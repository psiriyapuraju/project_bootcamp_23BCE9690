# %%
import pandas as pd

# %%
spreadsheet = pd.read_csv('Dataset.csv')

# %%
spreadsheet
# Out:
#      index            Genre  Year  Movies Released       Gross  Tickets Sold  \
# 0        0        Adventure  1995               29   771507571     177358047
# 1        1        Adventure  1996               34  1290490033     291966054
# 2        2        Adventure  1997               23   881902843     192135684
# 3        3        Adventure  1998               29  1614467732     344236174
# 4        4        Adventure  1999               27  1612432107     317407880
# ..     ...              ...   ...              ...         ...           ...
# 295    295  Multiple Genres  2017                5     4614134        514394
# 296    296  Multiple Genres  2018                3     4787450        533717
# 297    297          Reality  2014                1       16826          2059
# 298    298          Reality  2015                3      604870         71751
# 299    299          Reality  2018                1        2027           225
#
# ...

# %%
# For previewing the top few rows of the Dataframe(in this case 'spreadsheet')
spreadsheet.head()
# Out:
#    index      Genre  Year  Movies Released       Gross  Tickets Sold  \
# 0      0  Adventure  1995               29   771507571     177358047
# 1      1  Adventure  1996               34  1290490033     291966054
# 2      2  Adventure  1997               23   881902843     192135684
# 3      3  Adventure  1998               29  1614467732     344236174
# 4      4  Adventure  1999               27  1612432107     317407880
#
#    Inflation-Adjusted Gross                            Top Movie  \
# 0                1590901682                            Toy Story
# 1                2618935504                     Independence Day
# 2                1723457085                         Men in Black
# 3                3087798481                           Armageddon
# 4                2847148684  Star Wars Ep. I: The Phantom Menace
#
#    Top Movie Gross (That Year)  Top Movie Inflation-Adjusted Gross (That Year)
# 0                    150148222                                    3.096160e+08
# ...

# %%
# For previewing the bottom few rows of the Dataframe(in this case 'spreadsheet')
spreadsheet.tail()
# Out:
#      index            Genre  Year  Movies Released    Gross  Tickets Sold  \
# 295    295  Multiple Genres  2017                5  4614134        514394
# 296    296  Multiple Genres  2018                3  4787450        533717
# 297    297          Reality  2014                1    16826          2059
# 298    298          Reality  2015                3   604870         71751
# 299    299          Reality  2018                1     2027           225
#
#      Inflation-Adjusted Gross           Top Movie  \
# 295                   4614114   2017 Oscar Shorts
# 296                   4787441   2018 Oscar Shorts
# 297                     18469       The Principle
# 298                    643606  Benpao Ba! Xiongdi
# 299                      2018    The Cage Fighter
#
#      Top Movie Gross (That Year)  \
# 295                      2835355
# 296                      3508777
# 297                        16826
# 298                       309297
# 299                         2027
#
# ...

# %%
# Displays the distinct, non-repeating values from a particular column
spreadsheet['Year'].unique()
# Out:
# array([1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005,
#        2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016,
#        2017, 2018], dtype=int64)

# %%
# Displays the number of unique values from a particular column
spreadsheet['Year'].nunique()
# Out:
# 24

# %%
# Displays the number of times the value repeats
spreadsheet['Year'].value_counts()
# Out:
# 2015    14
# 2014    14
# 2007    13
# 2008    13
# 2017    13
# 2016    13
# 2013    13
# 2012    13
# 2011    13
# 2010    13
# 2009    13
# 2018    13
# 2006    13
# 2004    13
# 2003    13
# 2001    13
# 2000    13
# 2005    12
# 2002    12
# 1999    12
# 1996    11
# 1998    10
# 1997    10
# 1995    10
# Name: Year, dtype: int64

# %%
# Viewing separate rows
spreadsheet.iloc[2]
# Out:
# index                                                            2
# Genre                                                    Adventure
# Year                                                          1997
# Movies Released                                                 23
# Gross                                                    881902843
# Tickets Sold                                             192135684
# Inflation-Adjusted Gross                                1723457085
# Top Movie                                             Men in Black
# Top Movie Gross (That Year)                              250650052
# Top Movie Inflation-Adjusted Gross (That Year)    489832424.743661
# Name: 2, dtype: object

# %%
# Viewing separate columns
spreadsheet['Top Movie']
# Out:
# 0                                Toy Story
# 1                         Independence Day
# 2                             Men in Black
# 3                               Armageddon
# 4      Star Wars Ep. I: The Phantom Menace
#                       ...
# 295                      2017 Oscar Shorts
# 296                      2018 Oscar Shorts
# 297                          The Principle
# 298                     Benpao Ba! Xiongdi
# 299                       The Cage Fighter
# Name: Top Movie, Length: 300, dtype: object

# %%
# Dropping columns
spreadsheet = spreadsheet.drop('index', axis = 1)

# %%
spreadsheet
# Out:
#                Genre  Year  Movies Released       Gross  Tickets Sold  \
# 0          Adventure  1995               29   771507571     177358047
# 1          Adventure  1996               34  1290490033     291966054
# 2          Adventure  1997               23   881902843     192135684
# 3          Adventure  1998               29  1614467732     344236174
# 4          Adventure  1999               27  1612432107     317407880
# ..               ...   ...              ...         ...           ...
# 295  Multiple Genres  2017                5     4614134        514394
# 296  Multiple Genres  2018                3     4787450        533717
# 297          Reality  2014                1       16826          2059
# 298          Reality  2015                3      604870         71751
# 299          Reality  2018                1        2027           225
#
#      Inflation-Adjusted Gross                            Top Movie  \
# ...

# %%
# Dropping rows
spreadsheet = spreadsheet.drop(4, axis = 0)

# %%
spreadsheet
# Out:
#                Genre  Year  Movies Released       Gross  Tickets Sold  \
# 0          Adventure  1995               29   771507571     177358047
# 1          Adventure  1996               34  1290490033     291966054
# 2          Adventure  1997               23   881902843     192135684
# 3          Adventure  1998               29  1614467732     344236174
# 5          Adventure  2000               30  1327311892     246254507
# ..               ...   ...              ...         ...           ...
# 295  Multiple Genres  2017                5     4614134        514394
# 296  Multiple Genres  2018                3     4787450        533717
# 297          Reality  2014                1       16826          2059
# 298          Reality  2015                3      604870         71751
# 299          Reality  2018                1        2027           225
#
#      Inflation-Adjusted Gross                       Top Movie  \
# 0                  1590901682                       Toy Story
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
year = []
year = spreadsheet['Year'].tolist()
number = []
number = spreadsheet['Movies Released'].tolist()

# %%
plt.bar(year, number)
plt.xlabel('Years')
plt.ylabel('Number of Films released')
plt.title('Number of films released during the years 1995-2018')
plt.xlim(1994, 2019)
plt.ylim(0,300)
plt.grid(True)

# %%
plt.bar(year, number, color = 'green')
# Out:
# <BarContainer object of 299 artists>

# %%
plt.xlim(1994, 2019)
plt.ylim(0,300)
plt.xticks(range(1995,2019, 2))
plt.bar(year, number, color = 'lightgreen')
# Out:
# <BarContainer object of 299 artists>
